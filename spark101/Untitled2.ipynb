# %%
a = open('2019-03-19.txt', 'r').read().split('\n')

# %%
json.loads(a[1])['id_str']
# Out:
# '1108092027642744832'

# %%
import json
for i in a:
    json.loads(a1])['text']
    json.loads(i)['id']

# %%
from tweepy.streaming import StreamListener 
from tweepy import OAuthHandler
from tweepy import Stream
import twitter_credentials
import json

class TwitterStreamer():

    def __init__(self):
        pass

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
        auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
        stream = Stream(auth, listener)
        stream.filter(track=hash_tag_list)
        
class StdOutListener(StreamListener):
        
    def __init__(self, fetched_tweets_filename):        
        
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write({'id':json.loads(data)['id']
                         ,'text':json.loads(data)['text']})
            
            return True
        except BaseException as e:
            print("Error on_data {}".format(e))
        return True
    
    def on_error(self, status):
        print(status)
        
if __name__ == '__main__':
 
    hash_tag_list = ["bolsonaro"]
    fetched_tweets_filename = "tweets.txt"

    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# @washingtonpost Fake News. @washingtonpost “Shame” !!!
#
# Trend topics on @Twitter
#
# #BolsonaroOrgulhaOBrasil
#
# Bolso… https://t.co/fP6hXpYIeU
# 1108104900049813504
# Error on_data write() argument must be str, not dict
# RT @CarlaZambelli17: Trump elogia Eduardo Bolsonaro: “Tem sido fantástico”.
#
# Xiii, cadê a turminha que criticou meu colega de bancada por t…
# 1108104900930686976
# Error on_data write() argument must be str, not dict
# A diferencia de Colombia y Duque este como que si no anda con guabineo
# 1108104901190696962
# Error on_data write() argument must be str, not dict
# RT @PatriaAmada_Br: O presidente dos Estados Unidos, Donald Trump, afirmou no início da tarde desta terça-feira (19) q quer o governo de Ja…
# 1108104901622726658
# Error on_data write() argument must be str, not dict
# Grande momento!
#
# #BolsonaroOrgulhaOBrasil
# 1108104902646120448
# Error on_data write() argument must be str, not dict
# RT @Press_VZLA: URGENTE
#
# DECLARACIONES A LA PRENSA DEL PRESIDENTE DE EEUU Y DE BRASIL.
#
# Presidente Bolsonaro: "La intervención militar (en…
# 1108104902721576960
# Error on_data write() argument must be str, not dict
# RT @PauloVieiraReal: Bolsonaro acha chique assinar QUALQUER contrato com o governo americano. É o típico Brasileiro médio que queria ter na…
# 1108104902801268741
# Error on_data write() argument must be str, not dict
# RT @thehill: Jair Bolsonaro, President of Brazil: "It is a pleasure to be here in the United States after a few decades of Presidents in Br…
# 1108104902893551616
# Error on_data write() argument must be str, not dict
# RT @leonline2000: Hola @Miguel_Pizarro mira quién se pone en primera línea para la liberación de Venezuela.
#
# El que escupe para arriba, le…
# 1108104903338135559
# Error on_data write() argument must be str, not dict
# RT @henriolliveira: COM BOLSONARO
#
# - BOVESPA batendo recorde histórico
# - Presidente cuidando dos interesses do povo nos EUA
#
# COM O PT
#
# - It…
# 1108104903740788737
# Error on_data write() argument must be str, not dict
# RT @oscarcaceres: Senador Jaime Quintana advierte que visita de Jair Bolsonaro es una visita oficial y no visita de Estado, razón por la cu…
# 1108104904810352640
# Error on_data write() argument must be str, not dict
# RT @CrisMenshova: Bolsonaro orgulha o Brasil!
# #BolsonaroOrgulhaOBrasil https://t.co/zQ1OiF6fwj
# 1108104905083011073
# Error on_data write() argument must be str, not dict
# Quais tipos de assassinato o senhor tem motivos para ser mandante?
# 1108104905192103937
# Error on_data write() argument must be str, not dict
# RT @capixabacyclist: Esperando a esquerda espernear dizendo que nao existe o Foro de São Paulo, cujo Bolsonaro citou em seu pronunciamento.…
# 1108104905557004289
# Error on_data write() argument must be str, not dict
# RT @AnarquistaChefe: Captaram o áudio!
#
# #BolsonaroEnvergonhaOBrasil
#
#  "Trump e Bolsonaro" https://t.co/7NpKABVMMk
# 1108104905733083140
# Error on_data write() argument must be str, not dict
# RT @jairbolsonaro_2: Ansioso para o Grande encontro de Bolsonaro e nosso Querido Presidente Americano Donald Trump
# 1108104905754136576
# Error on_data write() argument must be str, not dict
# RT @gleisi: Bolsonaro desrespeita o povo brasileiro ao dizer que imigrantes que vão para os EUA não têm boa intenção. Quem não tem boa inte…
# 1108104906320285697
# Error on_data write() argument must be str, not dict
# RT @ThiagoKrause2: Ainda não entendi que cargos são esses. Se forem os de gestão (chefia de departamento e tal), as universidades param. Qu…
# 1108104906643247108
# Error on_data write() argument must be str, not dict
# RT @ReginaMunhoz4: #BolsonaroOrgulhaOBrasil
# #BolsonaroOrgulhaOBrasil
# #BolsonaroOrgulhaOBrasil
# Não vem  não ptralhada.
# Vai roendo o cotov…
# 1108104906949431297
# Error on_data write() argument must be str, not dict
# RT @Suxbernardo: Discurso do Bolsonaro nos EUA https://t.co/Cnjpsfot1K
# 1108104907347935233
# Error on_data write() argument must be str, not dict
# 🤣🤣🤣🤣🤣
# 1108104907360534528
# Error on_data write() argument must be str, not dict
# RT @andrefran: Bolsonaro, pra imprensa do mundo todo, ao lado de Trump, nos jardins da Casa Branca, disse que luta contra: a ideologia de g…
# 1108104907637358593
# Error on_data write() argument must be str, not dict
# GREVE GERAL AQUI E LÁ PARA DERROTA-LOS!...Bolsonaro capacho de Trump e dos EUA https://t.co/ZSffWLaOZM via @PSTU
# 1108104907893231617
# Error on_data write() argument must be str, not dict
# RT @Daqui2017: Bolsonaro a jornalistas: "Se por ventura, vierem à mesa, certas medidas não podem ser tornadas públicas."
# Que droga ele tomo…
# 1108104908056772614
# Error on_data write() argument must be str, not dict
# RT @PublimetroChile: Siguen los desaires a Bolsonaro: Presidente del Senado no irá al almuerzo oficial en La Moneda por "razones políticas"…
# 1108104908220350464
# Error on_data write() argument must be str, not dict
# RT @washingtonpost: "Shame."
#
# As Bolsonaro visits Trump, Brazilians tweet their embarrassment. https://t.co/6spO4Vypqt
# 1108104909147262979
# Error on_data write() argument must be str, not dict
# @lucaslafaiette @Cimaciel3 @MatiasSpektor OCDE não disseram nada de concreto. Alcântara é nossa, quem está conceden… https://t.co/i0ZkLwZrv7
# 1108104909159837697
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: Aliança com Otan traz ganhos em defesa e energia, diz Bolsonaro. https://t.co/AdvavmKvEO
# 1108104909461901313
# Error on_data write() argument must be str, not dict
# RT @JoelAlexandreM: Momento em que Trump elogia Eduardo Bolsonaro. #BolsonaroOrgulhodoBrasil https://t.co/zDx927uy9q
# 1108104909642178561
# Error on_data write() argument must be str, not dict
# RT @afccontador: Bolsonaro não tornou ninguém cruel, preconceituoso, racista, homofóbico, misógino, xenófobo, intolerante e idiota. Essas p…
# 1108104910342684678
# Error on_data write() argument must be str, not dict
# RT @Helenarubensl: Traidor da SEMANA! CoronelTelhada vota no PT para a presidência da Câmara de São Paulo. Afirma que fez isso porque "não…
# 1108104910539763713
# Error on_data write() argument must be str, not dict
# Bolsonaro tá é certo
# 1108104910892077057
# Error on_data write() argument must be str, not dict
# RT @InequalityMedia: As he meets with Brazil's far-right strongman leader Jair Bolsonaro today, here's why Trump has become America's most…
# 1108104911231832064
# Error on_data write() argument must be str, not dict
# RT @DrJillStein: #Venezuela's right-wing opposition wants to expel Cuban doctors, who told this to voters. US media spin this as "Maduro th…
# 1108104912536166400
# Error on_data write() argument must be str, not dict
# RT @_pinheira: Bolsonaro: "a maioria dos imigrantes não tem boas intenções".
#
# Não tem mesmo.
#
# Em Los Angeles, 90% dos brasileiros que lá vi…
# 1108104912846684160
# Error on_data write() argument must be str, not dict
# RT @50ChicoAlencar: Deixa eu ver se entendi: Bolsonaro é a favor do muro de Trump q impede imigrantes de entrarem nos EUA, mas abre as port…
# 1108104913463242752
# Error on_data write() argument must be str, not dict
# RT @senadorhumberto: TV norte-americana destaca comportamento homofóbico vexatório de Bolsonaro e ligação da família dele com milicianos e…
# 1108104913454800896
# Error on_data write() argument must be str, not dict
# Bolsonaro no descarta apoyar una posible intervención de EE.UU. en Venezuela https://t.co/jLEkzLRoLD
# 1108104913647747072
# Error on_data write() argument must be str, not dict
# RT @sensacionalista: Bolsonaro entrega base e visto aos EUA e ganha boné de Trump https://t.co/FCIHMiJd4k
# 1108104913832288260
# Error on_data write() argument must be str, not dict
# RT @ysanikalapalo: Namore alguém que olhe pra você como o Trump olha pro Bolsonaro😀😍
# #BolsonaroOrgulhaOBrasil https://t.co/lDZTUAVdEx
# 1108104914012725248
# Error on_data write() argument must be str, not dict
# RT @Thi4g0nes: @Miltonneves @jairbolsonaro A similaridade entre o Trump e o Bolsonaro nas candidaturas é de se invejar, ambos ridicularizad…
# 1108104914155290625
# Error on_data write() argument must be str, not dict
# RT @GuilhermeBoulos: Nos EUA, Paulo Guedes chamou Olavo de Carvalho de líder, quase ajoelhou para os americanos pra entrar na OCDE e anunci…
# 1108104914302091264
# Error on_data write() argument must be str, not dict
# RT @randolfeap: Se até a @foxnews, defensora do @realDonaldTrump, expõe as relações da família bolsonaro com milicianos, posturas racistas,…
# 1108104914205593601
# Error on_data write() argument must be str, not dict
# RT @NildoOuriques: Bolsonaro visitou a CIA. Acostumem-se:  não se trata de um idiota ou bruto na presidência: é uma exigência da guerra de…
# 1108104914377543680
# Error on_data write() argument must be str, not dict
# Na Casa Branca, Trump diz que apoia entrada do Brasil na OCDE https://t.co/x90c4h3mxM
# 1108104914482413568
# Error on_data write() argument must be str, not dict
# RT @herong: Ok, so why is it significant that Bolsonaro mentioned "gender ideology" at the presser with Trump?
#
# "Gender ideology" is a Rig…
# 1108104915027546112
# Error on_data write() argument must be str, not dict
# RT @delucca: Bolsonaro esta certo, eu acho que brasileiro que mora no exterior tem de ser tudo deportado mesmo, votaram em peso nessa desgr…
# 1108104915350683651
# Error on_data write() argument must be str, not dict
# RT @Andrelloopes: Logo mais o Bolsonaro vai postar um vídeo no Walmart pra mostrar as diferenças de preços em eletrônicos e outro sobre com…
# 1108104915510087680
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: Em entrevista a jornalistas, Jair Bolsonaro também justificou a isenção de vistos concedida a americanos. https://t.co/V…
# 1108104917623980043
# Error on_data write() argument must be str, not dict
# @augustosnunes A.N. parou pra pensar que vc só posta assuntos do PT ???? Esquece esses lixos que só atrasou o Brasi… https://t.co/PIXIsLOuO2
# 1108104917842046976
# Error on_data write() argument must be str, not dict
# 😂🥴
# 1108104918848688128
# Error on_data write() argument must be str, not dict
# RT @BiggThii: Aspas para Donald Trump:
#
# "É uma grande honra ter o Presidente Bolsonaro conosco vindo do Brasil, ele tem feito um trabalho…
# 1108104918622236673
# Error on_data write() argument must be str, not dict
# RT @MarcosCintra: Amanha o Presidente Bolsonaro assina protocolo com os EUA para reiniciar entendimentos sobre um acordo contra bi tributac…
# 1108104919133900800
# Error on_data write() argument must be str, not dict
# RT @CeciliaAF1: Quienes no van a programas porq habrá un panelista de derecha? Quienes se retiran del estudio de tv porq entra Maldonado? Q…
# 1108104919603654657
# Error on_data write() argument must be str, not dict
# RT @BiggThii: Aspas para Donald Trump:
#
# "É uma grande honra ter o Presidente Bolsonaro conosco vindo do Brasil, ele tem feito um trabalho…
# 1108104919964418049
# Error on_data write() argument must be str, not dict
# RT @jandira_feghali: Posicionamento do min. Fux sobre o sistema de repartição ser cláusula pétrea só reforça o quanto a reforma da Previdên…
# 1108104920627101696
# Error on_data write() argument must be str, not dict
# Encontro retoma uma antiga tradição de parceria e, ao mesmo tempo, abre um capítulo inédito da relação do Brasil co… https://t.co/VsLy012tcN
# 1108104920505507843
# Error on_data write() argument must be str, not dict
# RT @vladomirosevic: Recibí invitación de La Moneda para la recepción al Presidente de Brasil. Me negué a participar. Considero a Bolsonaro…
# 1108104920832499712
# Error on_data write() argument must be str, not dict
# RT @CrisMenshova: Fico imaginando Trump falando, no encontro com Bolsonaro: Brasil acima de tudo, Deus acima de todos... Os jornas teriam u…
# 1108104921314967552
# Error on_data write() argument must be str, not dict
# @supahdupahfky That’s exactly the point. Trump is not right wing. Trump is far-right. Farage is far-right. Stephen… https://t.co/VJ9dKmouWK
# 1108104921306537990
# Error on_data write() argument must be str, not dict
# RT @DeputadoFederal: #BolsonaroEnvergonhaOBrasil é o assunto mais comentado do Twitter no Brasil e o 3° mais comentado no mundo.
#
# Notícias…
# 1108104921788878848
# Error on_data write() argument must be str, not dict
# Maia e Alcolumbre vão dar agilidade ao trâmite da reforma, diz Flávio Bolsonaro -  https://t.co/k6EOJAQVMh
# 1108104921864421379
# Error on_data write() argument must be str, not dict
# RT @Caroexpress: Se imaginan la cantidad de negocios personales que harán Piñera y Bolsonaro?. Ambos con información privilegiada, fríos y…
# 1108104922141200391
# Error on_data write() argument must be str, not dict
# RT @cynaramenezes: agora, graças a bolsonaro, qualquer norte-americano pode entrar no brasil sem necessidade de visto.
# até aqueles malucos…
# 1108104922179035136
# Error on_data write() argument must be str, not dict
# RT @blogdojosias: Bolsonaro faz parceria com Trump, não com EUA https://t.co/4w2cOS8BNE via @UOLNoticias @UOL
# 1108104922522746881
# Error on_data write() argument must be str, not dict
# RT @cyrusafa: @g1 Mas é um lambe-botas...
# Primeiro,o filho ataca os brasileiros lá fora
# Depois o próprio Mijair ofende os brasileiros imigr…
# 1108104922833317888
# Error on_data write() argument must be str, not dict
# @extralicante @_asti_attano @JMilei @AgustinLaje @NickyMarquez1 ¿Si sabes que la izquierda no es precisamente homog… https://t.co/YefEdOhZFz
# 1108104923420524544
# Error on_data write() argument must be str, not dict
# @UOL Grande dia presidente Bolsonaro.  Quanto orgulho #BolsonaroOrgulhaOBrasil
# 1108104923684712448
# Error on_data write() argument must be str, not dict
# RT @IvanValente: Resultado do servilismo.
# Enquanto isso, os brasileiros seguem pagando.
#
# https://t.co/iswmPAJFiF
# 1108104924083245056
# Error on_data write() argument must be str, not dict
# RT @ysanikalapalo: Namore alguém que olhe pra você como o Trump olha pro Bolsonaro😀😍
# #BolsonaroOrgulhaOBrasil https://t.co/lDZTUAVdEx
# 1108104924011905030
# Error on_data write() argument must be str, not dict
# RT @fredlmartins: Visita surpresa à CIA? É só tocar o interfone que o porteiro avisa que a pessoa tá subindo? Isso em uma das principais ce…
# 1108104924745920513
# Error on_data write() argument must be str, not dict
# RT @MLeitoa: Obrigado Senhor por esse encontro ser entre Bolsonaro e Trump e não entre Haddad e Maduro! Amém! 🙏🏻
# 1108104924687204353
# Error on_data write() argument must be str, not dict
# RT @oftay_: O mundo tá tão estranho que a Fox News ataca mais o Bolsonaro que toda a imprensa brasileira
# 1108104925018550272
# Error on_data write() argument must be str, not dict
# RT @marcelorandes: E ACABA A NARRATIVA "Filhos do Bolsonaro causam problemas e devem ser afastados do presidente". De agora em diante, só e…
# 1108104925211475968
# Error on_data write() argument must be str, not dict
# RT @ekbufalo: Bolsonaro ha dicho una cosa evidente, pero que en la Venezuela contemporánea no se suele comprender: hay cosas que no se deve…
# 1108104925316349958
# Error on_data write() argument must be str, not dict
# RT @MidiaNINJA: Imigrante brasileiro nos Estados Unidos comenta fala de Bolsonaro no país: Uma mistura de viralatismo e entreguismo. #Bolso…
# 1108104925316292615
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: No meio da declaração à imprensa, Donald Trump elogiou o papel de Eduardo Bolsonaro nas relações internacionais. https:/…
# 1108104926213951488
# Error on_data write() argument must be str, not dict
# RT @delucca: Imagina como essa declaração do Bolsonaro, de que defende o muro que Trump quer construir entre os Estados Unidos e o México,…
# 1108104926692024328
# Error on_data write() argument must be str, not dict
# @LorenzonItalo resumindo, prometo lamber as bolas do Bolsonaro até ele gozar!!!! #goldenshowerpresident
# 1108104926721392641
# Error on_data write() argument must be str, not dict
# RT @JoelAlexandreM: Momento em que Trump elogia Eduardo Bolsonaro. #BolsonaroOrgulhodoBrasil https://t.co/zDx927uy9q
# 1108104926746603520
# Error on_data write() argument must be str, not dict
# RT @RenovaMidia: A presença do deputado Eduardo Bolsonaro (PSL-SP) no Salão Oval da Casa Branca não foi vista com bons olhos por alguns jor…
# 1108104926809505792
# Error on_data write() argument must be str, not dict
# Bolsonaro: reforma dos militares será aperfeiçoada, sem privilégios - Gazeta do Povo https://t.co/GZ5miNk8RL
# 1108104927027609607
# Error on_data write() argument must be str, not dict
# 1. Guaidó: Hemos comenzado a tomar control de las sedes diplomáticas de nuestro gobierno en los Estados Unidos. 2.… https://t.co/ltyADt5vAv
# 1108104928197787648
# Error on_data write() argument must be str, not dict
# RT @claudioedantas: Eduardo Bolsonaro ‘tem sido fantástico’, elogia Trump https://t.co/sTKzuA3EgM
# 1108104928394924032
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: No meio da declaração à imprensa, Donald Trump elogiou o papel de Eduardo Bolsonaro nas relações internacionais. https:/…
# 1108104929258950656
# Error on_data write() argument must be str, not dict
# RT @andrefran: Bolsonaro, pra imprensa do mundo todo, ao lado de Trump, nos jardins da Casa Branca, disse que luta contra: a ideologia de g…
# 1108104929456066593
# Error on_data write() argument must be str, not dict
# Parabéns meu amado PRESIDENTE Bolsonaro estamos felizes pelo nosso país
# 1108104929367994368
# Error on_data write() argument must be str, not dict
# RT @HenriqueFontana: Bolsonaro, o filho e Sérgio Moro fizeram uma visita surpresa para os amigos da CIA! Pelo jeito foram agradecer pelos c…
# 1108104929653280769
# Error on_data write() argument must be str, not dict
# RT @Haddad_Fernando: Sigilo quebrado: Bolsonaro encontrou-se com torturadora da CIA.  https://t.co/p8HbU2KAMN
# 1108104929976168449
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSP: Não estamos numa competição e todos os meus passos na área internacional são dados sob orientação do Ministro @ernestofara…
# 1108104930173349890
# Error on_data write() argument must be str, not dict
# RT @conexaopolitica: ÚLTIMAS: Trump elogia atuação de Eduardo Bolsonaro nas relações internacionais
#
# https://t.co/JiT4V4Xaql
# 1108104930466955264
# Error on_data write() argument must be str, not dict
# RT @heldersalomao: "Há muita fake news no Brasil", diz Bolsonaro a emissora americana.
#
# Falou o Presidente que foi eleito espalhando Fake N…
# 1108104931762991104
# Error on_data write() argument must be str, not dict
# RT @SergioNovelli: Creo que es como la sexta vez que lo dice... Trump reafirmó que “todas las opciones están sobre la mesa”. Lo dijo en rue…
# 1108104931792351237
# Error on_data write() argument must be str, not dict
# Bolsonaro pede desculpas por dizer que imigrantes têm más intenções https://t.co/0OvS7rae5G
# 1108104931876265984
# Error on_data write() argument must be str, not dict
# RT @randolfeap: Se até a @foxnews, defensora do @realDonaldTrump, expõe as relações da família bolsonaro com milicianos, posturas racistas,…
# 1108104932085952512
# Error on_data write() argument must be str, not dict
# RT @sandonaegui: Se salvó #Bolsonaro. Almuerzo, vino, atropello seguro. https://t.co/C1oWr1kh5T
# 1108104933461643264
# Error on_data write() argument must be str, not dict
# Após abrir Brasil aos EUA, Bolsonaro ganha de Trump camiseta com estampa "suspeita" | Revista Fórum https://t.co/1bLJfB6uBp
# 1108104933642027011
# Error on_data write() argument must be str, not dict
# RT @ntvde: Bolsonaro im Weißen Haus: Trump trifft Tropen-Trump https://t.co/wBWQzkWrOQ
# 1108104934535376896
# Error on_data write() argument must be str, not dict
# RT @pauloap: O termo FORO DE SÃO PAULO está nos trending topics, com muitos esquerdistas dizendo que o Bolsonaro divulgou um "boato de What…
# 1108104934715731969
# Error on_data write() argument must be str, not dict
# RT @Whackybus: O vice presidente até ontem era o Mourão. https://t.co/IKbdkLs6o7
# 1108104934824787968
# Error on_data write() argument must be str, not dict
# Na Casa Branca, Trump diz que apoia entrada do Brasil na OCDE https://t.co/7XVlwDBRAU
# 1108104935680425985
# Error on_data write() argument must be str, not dict
# É isso que estou falando.
# Pessoas, cidadãos, que votaram em Bolsonaro, que votaram por um país sem corrupção, que… https://t.co/j59HZWQui3
# 1108104935961477125
# Error on_data write() argument must be str, not dict
# RT @EErlandsen: La vergüenza no es pedirle a las damas que vayan de "vestido corto" (esa es una redacción poco feliz)
# La vergüenza y el ins…
# 1108104936401915907
# Error on_data write() argument must be str, not dict
# RT @andrizek: 'Grande maioria dos imigrantes não tem boas intenções”. Que vergonha o presidente de um país erguido por imigrantes falar iss…
# 1108104936376549377
# Error on_data write() argument must be str, not dict
# RT @RogerioCorreia_: Bolsonaro envergonha o Brasil no mundo, mas "tem" um belo hino. “Aluga-se”, de Raul Seixas e Claudio Roberto Azeredo,…
# 1108104936435449858
# Error on_data write() argument must be str, not dict
# Ele é descendente de imigrantes né?! Ah tá, só pra constar.
# 1108104937014284289
# Error on_data write() argument must be str, not dict
# RT @AlemaoSextaVez: Eu sinto ORGULHO do meu presidente Jair Bolsonaro.
#
# E você?
# 1108104937580437509
# Error on_data write() argument must be str, not dict
# @JoelAlexandreM O tal Gugu chacra estava de mimimi "ai que o Eduardo Bolsonaro deu bola fora, ele se reuniu com des… https://t.co/NjnlNjiA1e
# 1108104937626632194
# Error on_data write() argument must be str, not dict
# RT @khr_santos: Trump elogiando @BolsonaroSP...
#
# Se a esquerda já estava no ódio, agora ela morre de vez e leva junto os folhetins de fundo…
# 1108104937697738752
# Error on_data write() argument must be str, not dict
# RT @IvanOlguin: En protocolo, "vestido largo" es temida formal para mujeres; y "vestido corto" es tenida semi formal para mujeres. La ultra…
# 1108104937777565702
# Error on_data write() argument must be str, not dict
# RT @gabriel40026091: a cada dia que passa ele desvaloriza a gente num grau. "Eles não vão ao Brasil para procurar emprego" KKKKKKKKKKKKKK t…
# 1108104937781772289
# Error on_data write() argument must be str, not dict
# RT @AlemaoSextaVez: Eu sinto ORGULHO do meu presidente Jair Bolsonaro.
#
# E você?
# 1108104936456372225
# Error on_data write() argument must be str, not dict
# RT @JoelAlexandreM: Trump e Bolsonaro coletiva de imprensa. #BolsoTrump https://t.co/2SEMxs5fNV
# 1108104938029285376
# Error on_data write() argument must be str, not dict
# RT @CantoQueiroz: A esquerda derrotada por Trump e Bolsonaro. Grande dia! 👍🏻 A esquerda histérica surta 😂
# #BolsonaroOrgulhaOBrasil #BolsoTr…
# 1108104938427727872
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSP: Não estamos numa competição e todos os meus passos na área internacional são dados sob orientação do Ministro @ernestofara…
# 1108104938536738816
# Error on_data write() argument must be str, not dict
# RT @carloscezarcjr: Bolsonaro hoje esteve ao lado do homem mais poderoso do mundo dentro da nação mais poderosa do mundo, que compartilha d…
# 1108104938620637184
# Error on_data write() argument must be str, not dict
# os caras só querem trabalhar lá e girar dinheiro no país, não querem fazer o bem não...
# 1108104938956165121
# Error on_data write() argument must be str, not dict
# RT @igorrealequatro: Amadas se um namorado te tratar igual o Trump trata o Bolsonaro eu acho que você nem precisa de...tarô
# 1108104939090382849
# Error on_data write() argument must be str, not dict
# DONALD TRUMP SE REUNIÓ CON BOLSONARO EN WASHINGTON
#
# El informe de @segregustavo, socio director de Center Group y a… https://t.co/TiALPoIQGC
# 1108104939010691072
# Error on_data write() argument must be str, not dict
# RT @leandroruschel: Não pensem que nos EUA não existe extrema-imprensa. O Washington Post, o mais esquerdopata dos grandes jornais, acabou…
# 1108104938998165505
# Error on_data write() argument must be str, not dict
# RT @ysanikalapalo: Namore alguém que olhe pra você como o Trump olha pro Bolsonaro😀😍
# #BolsonaroOrgulhaOBrasil https://t.co/lDZTUAVdEx
# 1108104939446915074
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSub: Things that the traditional media doesnt show you:
#
# Dilma spent 200 thousand reais in luxury cars when she was in USA whi…
# 1108104939606286337
# Error on_data write() argument must be str, not dict
# RT @nadanovonofront: Numa coisa Malafaia tá certo: a grande novidade eleitoral em relação a 2014 foi que entre 60 e 65% dos evangélicos vot…
# 1108104940256456704
# Error on_data write() argument must be str, not dict
# RT @bidu___: Poxa esquerdalha vocês não gostam q o Bolsonaro tenha afeto pelos EUA?
#
# Votamos pra ele fazer exatamente o que vcs não gostam,…
# 1108104940285763585
# Error on_data write() argument must be str, not dict
# RT @delucca: Bolsonaro foi perguntado pela Fox News sobre Marielle Franco. Poderia dizer que as mobilizações são grandes, que lamenta o cri…
# 1108104940705251330
# Error on_data write() argument must be str, not dict
# RT @netoaires38: Trump fechando porta da Casa Branca depois da reunião de 8 minutos com Bolsonaro https://t.co/YFwQEf5LPv
# 1108104941124628481
# Error on_data write() argument must be str, not dict
# RT @alexaguiarpoa: Bolsonaro no Salão Oval da Casa Branca com o busto de MLK ao fundo.
#
# “Nothing in the world is more dangerous than sincer…
# 1108104941154066432
# Error on_data write() argument must be str, not dict
# RT @vanadias: O Presidente Bolsonaro aperta a mão de Trump, na chegada da Casa Branca ⚠️
#
# #BolsoTrump
# #BolsonaroOrgulhaOBrasil https://t.c…
# 1108104941292474374
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: Aliança com Otan traz ganhos em defesa e energia, diz Bolsonaro. https://t.co/AdvavmKvEO
# 1108104941602783232
# Error on_data write() argument must be str, not dict
# Jair Bolsonaro: Brasil y EE UU deben liberar a Venezuela https://t.co/C5HU6lR2EH   https://t.co/zaICYhuK83
# 1108104941720268800
# Error on_data write() argument must be str, not dict
# RT @uczai: Bolsonaro entregou a base de Alcântara aos EUA; permite a entrada de norte-americanos no Brasil sem visto (brasileiros continuam…
# 1108104941892190208
# Error on_data write() argument must be str, not dict
# RT @RogerioCorreia_: Importante este vídeo com o ex-ministro Carlos Gabas, um dos maiores especialistas em Previdência no Brasil. Em apenas…
# 1108104941808308225
# Error on_data write() argument must be str, not dict
# RT @MarcosCintra: Amanha o Presidente Bolsonaro assina protocolo com os EUA para reiniciar entendimentos sobre um acordo contra bi tributac…
# 1108104942039023621
# Error on_data write() argument must be str, not dict
# RT @SergioNovelli: Creo que es como la sexta vez que lo dice... Trump reafirmó que “todas las opciones están sobre la mesa”. Lo dijo en rue…
# 1108104942303277057
# Error on_data write() argument must be str, not dict
# RT @professorigor: A visita de Bolsonaro aos USA inspirou. Mando essa para Gilmar Mendes:
#
# Quando as pessoas temem o governo, isso é tirani…
# 1108104942928232451
# Error on_data write() argument must be str, not dict
# RT @FelipeM75454077: Tenho Orgulho sim do Bolsonaro!
# Todo mundo sabe que se fosse o Haddad o presidente, o encontro nesse momento seria com…
# 1108104942986977280
# Error on_data write() argument must be str, not dict
# RT @Miltonneves: Um banho de Casa Branca fortalece qualquer um. Foi o batismo mundial que faltava para Bolsonaro que, agora, há de determin…
# 1108104944450785280
# Error on_data write() argument must be str, not dict
# RT @TheGodFather_75: 19/03 #BolsonaroOrgulhaOBrasil
#
# 20/03 Aniversário do Bolsonaro
#
# 👍🏻 https://t.co/9DBaGyHeD4
# 1108104945331552257
# Error on_data write() argument must be str, not dict
# RT @luisnassif: Bolsonaro produziu em 15 minutos sujeira que americanos levam uma década para fazer. https://t.co/5yYWrF553F
# 1108104945859997697
# Error on_data write() argument must be str, not dict
# RT @PatoCorporation: A Fox News chamou Bolsonaro de fascista, exibiu a relação dele e s sua família c milícias, questionou seu envolvimento…
# 1108104946363351040
# Error on_data write() argument must be str, not dict
# RT @JoaquinTex: BOLSONARO E UM HOMEM SIMPLES E HUMILDE, NÃO ACOSTUMADO A TRANSITAR EM PALÁCIOS E BANQUETES. MAS TRANSMITE SINCERIDADE, INTE…
# 1108104946627629056
# Error on_data write() argument must be str, not dict
# RT @catturd2: At presser ... Brazilian President Bolsonaro Says Trump Will Win Reelection – Trump Responds, “Thank You, I Agree”
#
# God, I l…
# 1108104947252359168
# Error on_data write() argument must be str, not dict
# QUERO MAIS!
# Batatinha quando nasce espalha a rama pelo chão,
#  meu presidente tá na casa Branca e o teu tá na prisão… https://t.co/42v6cI6uPL
# 1108104947374141441
# Error on_data write() argument must be str, not dict
# RT @Fasalles: Legal escutar os cliques das câmeras! Que chique!
# #BolsonaroOrgulhaoBrasil https://t.co/y1llQ2FLFe
# 1108104947504156672
# Error on_data write() argument must be str, not dict
# RT @PauloVieiraReal: Bolsonaro acha chique assinar QUALQUER contrato com o governo americano. É o típico Brasileiro médio que queria ter na…
# 1108104948116525056
# Error on_data write() argument must be str, not dict
# RT @ColumbiaBugle: President Bolsonaro: "In conclusion, Brazil &amp; the U.S. stand side-by-side in their efforts to ensure liberty, and respec…
# 1108104948040908800
# Error on_data write() argument must be str, not dict
# RT @davidmackau: Bolsonaro — who's said he wouldn't rape a woman bc she didn't "deserve" it &amp; that he hoped his son would die, rather than…
# 1108104948632293378
# Error on_data write() argument must be str, not dict
# @MiriamLeitaoCom É engraçado ver essa senhora chorar por bolsonaro. Isso só pode ser amor não correspondido .
# 1108104948657672193
# Error on_data write() argument must be str, not dict
# O presidente dos Estados Unidos, Donald Trump, afirmou no início da tarde desta terça-feira (19) que quer o governo… https://t.co/kHUfDbjQrm
# 1108104947621605376
# Error on_data write() argument must be str, not dict
# RT @samiabomfim: Quem acompanhou Jair Bolsonaro na reunião reservada com Donald Trump no salão oval foi seu filho Eduardo e não o ministro…
# 1108104949064437761
# Error on_data write() argument must be str, not dict
# RT @Nina_N___: @RobertoUebel https://t.co/AHA39guvTb
#
# Olha q legal
# 1108104949701976064
# Error on_data write() argument must be str, not dict
# RT @republica_ctba: Nos EUA, Bolsonaro critica Lula e Dilma: “andavam de mãos dadas com a corrupção” https://t.co/zmrBAAFkUD
# 1108104950180204545
# Error on_data write() argument must be str, not dict
# RT @JoelAlexandreM: Momento em que Trump elogia Eduardo Bolsonaro. #BolsonaroOrgulhodoBrasil https://t.co/zDx927uy9q
# 1108104950641557505
# Error on_data write() argument must be str, not dict
# RT @analisdocsPF: Precisamos de um amigo maior que nós. Estou feliz, simpatizo com os EUA. 😘Bolsonaro com Trump é interessantíssimo. Eles t…
# 1108104950817714177
# Error on_data write() argument must be str, not dict
# Ele tinha errado naquela declaração anterior, isso é óbvio e não importava qual era o contexto. Prefiro um presiden… https://t.co/hIhiuUDodu
# 1108104950675066880
# Error on_data write() argument must be str, not dict
# RT @professorigor: A visita de Bolsonaro aos USA inspirou. Mando essa para Gilmar Mendes:
#
# Quando as pessoas temem o governo, isso é tirani…
# 1108104951237095429
# Error on_data write() argument must be str, not dict
# RT @BereniceVieir11: AI FOI PRA MATAR,DÊ EMOÇÃO TODOS NÓS.. https://t.co/K0T3WYViGA
# 1108104951354544128
# Error on_data write() argument must be str, not dict
# RT @lareveron10: Donald Trump le dice a Jair Bolsonaro: "Brasil y EEUU nunca han estado más cerca". Vía: @AFPespanol #19Mar
# 1108104952013115392
# Error on_data write() argument must be str, not dict
# RT @RaquelBlak: Chupem Lulinhas !!!!!! Trump elogia , Eduardo Bolsonaro!
# #BolsoTrump https://t.co/jUqEEC6aKI
# 1108104952398909441
# Error on_data write() argument must be str, not dict
# RT @delucca: Bolsonaro foi perguntado pela Fox News sobre Marielle Franco. Poderia dizer que as mobilizações são grandes, que lamenta o cri…
# 1108104952415731712
# Error on_data write() argument must be str, not dict
# RT @igoraraujojj: Tudo que o Bolsonaro fizer ou falar, vai ser usado contra ele no tribunal canhoto. Se o Brasil amanhã, passar a ser o men…
# 1108104952830816256
# Error on_data write() argument must be str, not dict
# RT @cynaramenezes: bolsonaro visitou a central de inteligência dos EUA, a CIA.
#
# bem, essa será a única vez que você verá "bolsonaro" e "int…
# 1108104952705097728
# Error on_data write() argument must be str, not dict
# RT @professorigor: A visita de Bolsonaro aos USA inspirou. Mando essa para Gilmar Mendes:
#
# Quando as pessoas temem o governo, isso é tirani…
# 1108104953036443648
# Error on_data write() argument must be str, not dict
# #BolsonaroOrgulhaOBrasil
# 1108104953959276545
# Error on_data write() argument must be str, not dict
# RT @BohnGass: O que ficou nas entrelinhas da conversa entre Trump e Bolsonaro sobre a Venezuela é extremamente preocupante. Só o que falta,…
# 1108104954244489217
# Error on_data write() argument must be str, not dict
# RT @carlosjordy: Bolsonaro vai aos EUA: Incrementar as relações comerciais entre os 2 países; fortalecer a parceria p/ a segurança e defesa…
# 1108104954454175745
# Error on_data write() argument must be str, not dict
# RT @netoaires38: Trump fechando porta da Casa Branca depois da reunião de 8 minutos com Bolsonaro https://t.co/YFwQEf5LPv
# 1108104954617741312
# Error on_data write() argument must be str, not dict
# Meu ódio pelo Jair Bolsonaro só aumenta, e isso não quer dizer que eu apoio o PT, eu não gosto dele porq ele é um m… https://t.co/QxJb3wwTgj
# 1108104954806448128
# Error on_data write() argument must be str, not dict
# Falou o idiota que aplaudiu a ANTA ir dizer que houve “golpe” no Brasil e aplaude agora o “donut burner” dizer que… https://t.co/JGSzKFfVpZ
# 1108104955154575360
# Error on_data write() argument must be str, not dict
# RT @InriSincero: o Brasil perde a sua soberania  diante de outros países entre eles os USA por causa da submissão d Bolsonaro à Trump e pra…
# 1108104955674664961
# Error on_data write() argument must be str, not dict
# RT @pauloap: O termo FORO DE SÃO PAULO está nos trending topics, com muitos esquerdistas dizendo que o Bolsonaro divulgou um "boato de What…
# 1108104956152872960
# Error on_data write() argument must be str, not dict
# RT @Al_jazeeravt: Eu falei que o Edu faz um trabalho brilhante fora do país, está aí Trump elogiando. https://t.co/RMQ2UnDhLg
# 1108104956534497280
# Error on_data write() argument must be str, not dict
# #BolsonaroOrgulhaOBrasil
# 1108104956706467841
# Error on_data write() argument must be str, not dict
# Estados Unidos acima de tudo, burrice acima de todos
# 1108104956823904256
# Error on_data write() argument must be str, not dict
# RT @rdgwendel: Claramente bolsonaro com seu ótimo inglês explicou pro trump o que é golden shower https://t.co/vMKH3HaeM6
# 1108104957834813440
# Error on_data write() argument must be str, not dict
# RT @RepRoKhanna: As Bolsonaro tours the CIA and meets Trump at the White House, we must speak out against his human rights abuses and attac…
# 1108104958132408320
# Error on_data write() argument must be str, not dict
# Kkkkk
# 1108104958963056646
# Error on_data write() argument must be str, not dict
# RT @Acosta: Bolsonaro mentions the term “fake news” at joint news conference, drawing a reaction from Trump who smiled.
# 1108104959084527617
# Error on_data write() argument must be str, not dict
# RT @catturd2: At presser ... Brazilian President Bolsonaro Says Trump Will Win Reelection – Trump Responds, “Thank You, I Agree”
#
# God, I l…
# 1108104959252463616
# Error on_data write() argument must be str, not dict
# RT @xicosa: De joelhos https://t.co/MoHSR8Vwkj
# 1108104959248220160
# Error on_data write() argument must be str, not dict
# RT @PauloVieiraReal: Bolsonaro acha chique assinar QUALQUER contrato com o governo americano. É o típico Brasileiro médio que queria ter na…
# 1108104959973867520
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSP: Não estamos numa competição e todos os meus passos na área internacional são dados sob orientação do Ministro @ernestofara…
# 1108104960103927813
# Error on_data write() argument must be str, not dict
# RT @foIha_sp: Bolsonaro assina contrato de venda da Amazônia para Estados Unidos e dispara: "Já temos mato e quilombolas o suficiente!" htt…
# 1108104961018265601
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSP: Não estamos numa competição e todos os meus passos na área internacional são dados sob orientação do Ministro @ernestofara…
# 1108104961211150336
# Error on_data write() argument must be str, not dict
# RT @dimacgarcia: "Bolsonaro não é nome certo para o 2° turno, diz especialista".
#
# O preço da liberdade é a eterna vigilância. #BolsonaroOrg…
# 1108104960615559170
# Error on_data write() argument must be str, not dict
# RT @Filipe_cokinho: Os tweets do @mizanzuk envelhecem mal. Hoje temos o grande encontro desses "líderes" ¯\_(ツ)_/¯ https://t.co/M7D0NtK0dc
# 1108104961823526912
# Error on_data write() argument must be str, not dict
# RT @ParkerMolloy: Super cool that news organizations are shrugging off Bolsonaro's human rights abuses in favor of descriptions like "Twitt…
# 1108104963023138821
# Error on_data write() argument must be str, not dict
# a nova "mãe Diná" de topete!!!
# 1108104963404775425
# Error on_data write() argument must be str, not dict
# RT @dep_padrejoao: O queremos: representantes que nos encham de orgulho.
#
# O que temos: Bolsonaro e sua comitiva entregando o Brasil
#
# #Bolso…
# 1108104963627069446
# Error on_data write() argument must be str, not dict
# RT @piedadcordoba: Los asesinos de Marielle Franco resultaron ser paramilitares amigotes del hijo de Bolsonaro... los mismos que clamaban "…
# 1108104963656421376
# Error on_data write() argument must be str, not dict
# RT @GugaNoblat: Avisa ao Bolsonaro que ele não tava conversando com um grupo de WhatsApp . Era um pronunciamento para o mundo ver. Citar fo…
# 1108104964126228482
# Error on_data write() argument must be str, not dict
# RT @Dayxrocha: A imprensa vai ao delírio 🤣🤣🤣🇧🇷🇺🇸😎👉🏽👉🏽 https://t.co/KxSsIPpRBD
# 1108104964814131201
# Error on_data write() argument must be str, not dict
# RT @AmbJohnBolton: POTUS had working visit and lunch today with President Jair Bolsonaro of Brazil. They re-affirmed a new, historic partne…
# 1108104965028003841
# Error on_data write() argument must be str, not dict
# RT @cvpayne: Tropical Trump
# President Bolsonaro of Brazil says he is taking a stand against "fake news"
# 1108104965371908098
# Error on_data write() argument must be str, not dict
# RT @GugaNoblat: Avisa ao Bolsonaro que ele não tava conversando com um grupo de WhatsApp . Era um pronunciamento para o mundo ver. Citar fo…
# 1108104965699055618
# Error on_data write() argument must be str, not dict
# RT @leandroruschel: A parte mais surpreendente da coletiva de Bolsonaro e Trump foi a sugestão, mesmo que tênue, de uma aliança militar ent…
# 1108104965736804354
# Error on_data write() argument must be str, not dict
# RT @cristinaarfrei1: Bolsonaro coloca robos pra levantar a tag bolsonaro orgulho do brasil, qualquer um  com apenas dois neurônios não seri…
# 1108104965866876928
# Error on_data write() argument must be str, not dict
# @lilian_tahan Mourão tá melhor que o Jair Bolsonaro.
# 1108104966005317633
# Error on_data write() argument must be str, not dict
# RT @TapiaNic0: Cuando era diputado Bolsonaro tenia un letrero en su oficina contra los detenidos desaparecidos que decia:
#
# QUIEN BUSCA HUES…
# 1108104966118494208
# Error on_data write() argument must be str, not dict
# RT @VJacobergerL: Last prediction just before #BolsonaroNosEUA #trump : « If it continues that way, it'll be over in 6 months ». Who said t…
# 1108104967951446017
# Error on_data write() argument must be str, not dict
# RT @leonline2000: Hola @Miguel_Pizarro mira quién se pone en primera línea para la liberación de Venezuela.
#
# El que escupe para arriba, le…
# 1108104968064638987
# Error on_data write() argument must be str, not dict
# Esse MBL nunca me enganou.
# #BolsonaroOrgulhaOBrasil
# 1108104968568012802
# Error on_data write() argument must be str, not dict
# RT @IlhanMN: Brazilian President Bolsonaro has:
#
# -Praised torture
# -Called refugees "scum of the world"
# -Compared same-sex adoption to pedop…
# 1108104968454713344
# Error on_data write() argument must be str, not dict
# RT @gabrielmgatti: A gente não esquece. PSDB c/ apoio da mídia difundiu ideia q o PT era uma quadrilha. Aécio e Richa enchiam a boca p/ pro…
# 1108104969020944384
# Error on_data write() argument must be str, not dict
# RT @palmeriodoria: Bolsonaro mostrou nos States que não está preparado para o troca-troca. Ele só dá.
# 1108104969146773505
# Error on_data write() argument must be str, not dict
# RT @delucca: Bolsonaro esta certo, eu acho que brasileiro que mora no exterior tem de ser tudo deportado mesmo, votaram em peso nessa desgr…
# 1108104969138438146
# Error on_data write() argument must be str, not dict
# RT @SocialPowerOne1: Fox News anchor touts Brazil's Bolsonaro as a bulwark against socialists in Mexico and Venezuela https://t.co/JEDUnCw2…
# 1108104969234927617
# Error on_data write() argument must be str, not dict
# RT @felipe_autran: Muita vergonha. Bolsonaro não cansa de rebaixar as instituições REPUBLICANAS. Não se mistura família com governo. https:…
# 1108104969650163712
# Error on_data write() argument must be str, not dict
# #BolsonaroEnvergonhaOBrasil
# 1108104970094739456
# Error on_data write() argument must be str, not dict
# Na reunião entre os presidentes, Bolsonaro ofereceu o filho @CarlosBolsonaro para ajudar na campanha de 2020  do P.… https://t.co/AAkvO0yyZ2
# 1108104969566277638
# Error on_data write() argument must be str, not dict
# RT @periodicovzlano: ¡Se viene joropo! Bolsonaro tomará medida contra Maduro https://t.co/nAyTJmXsYB https://t.co/WkEJWqHopU
# 1108104971424284672
# Error on_data write() argument must be str, not dict
# RT @ananiasfernanda: Galera, a tag certa é #BolsonaroOrgulhaOBrasil !! E não “Bolsonaro orgulho do Brasil”, talkei?
# 1108104971688558593
# Error on_data write() argument must be str, not dict
# RT @samiabomfim: A postura subserviente de Jair Bolsonaro diante do boçal Donald Trump é uma demonstração de sua incapacidade de defender o…
# 1108104972435103744
# Error on_data write() argument must be str, not dict
# RT @LucioQuincioC: EN VIDEO: Bolsonaro asegura que de haber una "intervención" en Venezuela, no sería un tema público https://t.co/SMUyNSxc…
# 1108104972439298048
# Error on_data write() argument must be str, not dict
# RT @randolfeap: Será que @bolsonaro irá ameaçar a imprensa americana também? #FoxNews
# 1108104972695162886
# Error on_data write() argument must be str, not dict
# RT @professorigor: A visita de Bolsonaro aos USA inspirou. Mando essa para Gilmar Mendes:
#
# Quando as pessoas temem o governo, isso é tirani…
# 1108104972749733888
# Error on_data write() argument must be str, not dict
# RT @vanadias: O Presidente Bolsonaro aperta a mão de Trump, na chegada da Casa Branca ⚠️
#
# #BolsoTrump
# #BolsonaroOrgulhaOBrasil https://t.c…
# 1108104972900712448
# Error on_data write() argument must be str, not dict
# RT @247Barril: -Bolsonaro buscando parceria com os EUA;
# -Guedes gastando o Inglês e dando aula de economia nos EUA;
# -Moro buscando parceria…
# 1108104973160714246
# Error on_data write() argument must be str, not dict
# RT @folha: Líderes da Câmara querem limitar indicação política no governo Bolsonaro https://t.co/JNEy42SYU0
# 1108104973127241730
# Error on_data write() argument must be str, not dict
# #BolsonaroOrgulhaOBrasil verdade
# 1108104973181689857
# Error on_data write() argument must be str, not dict
# RT @mdenser: Parabéns aos brasileiros ilegais dos EUA onde a votação em Bolsonaro superou os 70%: agora vcs serão denunciados pelo pp consu…
# 1108104973836013570
# Error on_data write() argument must be str, not dict
# RT @CatSparrow_01: Enquanto nossa TV tenta a todo custo destruir ...
# A TV Americana FOX NEWS fez essa homenagem ao Bolsonaro para rodar o m…
# 1108104974003769350
# Error on_data write() argument must be str, not dict
# RT @HistoriaNoPaint: Só tá faltando o Bolsonaro voltar com a antiga bandeira do Brasil e com o nome "Estados Unidos do Brasil". Se bem que…
# 1108104974150586368
# Error on_data write() argument must be str, not dict
# RT @RogerNumeriano: Hoje foi um Grande Dia, #BolsonaroOrgulhaOBrasil:
#
# - Trump declara apoio à entrada do Brasil na OCDE;
# - Trump diz q Edu…
# 1108104974339371010
# Error on_data write() argument must be str, not dict
# RT @claudianoseua: Declaração de Bolsonaro de apoio à reeleição de Trump pode complicar relação Brasil-EUA caso 1 democrata vença em 2020.…
# 1108104974737788928
# Error on_data write() argument must be str, not dict
# Esse é meu presidente...
# 1108104975241097217
# Error on_data write() argument must be str, not dict
# RT @IlhanMN: Brazilian President Bolsonaro has:
#
# -Praised torture
# -Called refugees "scum of the world"
# -Compared same-sex adoption to pedop…
# 1108104975341813760
# Error on_data write() argument must be str, not dict
# Bolsonaro O Melhor....!
# #BolsonaroOrgulhaOBrasil
# #BolsonaroOrgulhoDoBrasil
# #BolsoTrump
# #BolsonaroNosEUA
# 1108104975924846593
# Error on_data write() argument must be str, not dict
# RT @henriolliveira: BOLSONARO e TRUMP juntos mostram ao mundo que o Brasil se livrou das garras da corja vermelha.
#
# E se Deus quiser, a pet…
# 1108104976222642181
# Error on_data write() argument must be str, not dict
# RT @InriSincero: Bolsonaro  abriu mão  de visto para americanos  entrarem no Brasil e em troca ganhou uma camiseta da seleção  americana.…
# 1108104976348442626
# Error on_data write() argument must be str, not dict
# RT @Ro_Moller: Tem uma militância aí, que diz que Jair Bolsonaro envergonha o Brasil, sabe quem são eles?????? Os mesmos que idolatram um P…
# 1108104976692404226
# Error on_data write() argument must be str, not dict
# RT @LiloVLOG: "É esse decreto aqui que você queria?" Entendedores entenderão. https://t.co/EmgMv0aSRq
# 1108104976834924544
# Error on_data write() argument must be str, not dict
# RT @acababolso: 1384 dias para o fim do governo Bolsonaro
# 1108104977397047296
# Error on_data write() argument must be str, not dict
# RT @sandonaegui: Se salvó #Bolsonaro. Almuerzo, vino, atropello seguro. https://t.co/C1oWr1kh5T
# 1108104977745092608
# Error on_data write() argument must be str, not dict
# RT @professorigor: Em 2014 Jean Willis ofendia Bolsonaro e Aécio Neves perseguia o então jornalista Jorge Kajuru.
#
# Em 2018 @jairbolsonaro e…
# 1108104978156134406
# Error on_data write() argument must be str, not dict
# RT @terca_livre: Bolsonaro se reúne com secretário geral da OEA -
# https://t.co/p0n6m21jo9
# 1108104978164527110
# Error on_data write() argument must be str, not dict
# RT @taliriapetrone: O grande acordo que Bolsonaro conseguiu nos Estados Unidos: em troca de lançamento em nossas bases aéreas e liberação d…
# 1108104978273652739
# Error on_data write() argument must be str, not dict
# RT @alessandromolon: Um presidente bajulador não é apenas uma vergonha p/ o Brasil, mas também um perigo. Bolsonaro deu a entender que apoi…
# 1108104980014206977
# Error on_data write() argument must be str, not dict
# RT @EdgeofSports: As Bolsonaro is feted by Trump, I know Brazilians in DC who wanted to speak at a rally on Sunday, but didn't out of fear…
# 1108104980291112960
# Error on_data write() argument must be str, not dict
# RT @igorrealequatro: Amadas se um namorado te tratar igual o Trump trata o Bolsonaro eu acho que você nem precisa de...tarô
# 1108104981255729154
# Error on_data write() argument must be str, not dict
# RT @jovensreacinhas: Bolsonaro foi aos EUA para lamber o saco do Trump e entregar o Brasil para os americanos
#
# Como retribuição os american…
# 1108104981327028224
# Error on_data write() argument must be str, not dict
# Na Casa Branca, Trump diz que apoia entrada do Brasil na OCDE https://t.co/y38IaWBwrw
# 1108104981922619393
# Error on_data write() argument must be str, not dict
# TRUMP copiando BOLSONARO😎🇺🇸🇧🇷✌👉
# EPISÓDIO 106° #BolsoTrump https://t.co/fvx0wK9Pm4
# 1108104981767438341
# Error on_data write() argument must be str, not dict
# RT @GabrieIaHardt: Amigos que tal um abaixo assinado com um milhão de assinaturas pedindo uma resposta, sobre o ex integrante do pt e PSOL,…
# 1108104982761562115
# Error on_data write() argument must be str, not dict
# O patético #BolsonaroEnvergonhaOBrasil
# 1108104982765727744
# Error on_data write() argument must be str, not dict
# RT @lelispatricia: A Fox News fez direitinho o trabalho!
# ...
# -Guedes gastando o Inglês e dando aula de economia nos EUA;
# -Moro buscando parceria…
# 1108104990298701826
# Error on_data write() argument must be str, not dict
# RT @RenovaMidia: "O trabalho do filho do presidente tem sido fantástico", afirmou o presidente dos #EUA, Donald Trump, sobre o deputado Edu…
# 1108104991078825984
# Error on_data write() argument must be str, not dict
# bolsonaro (indiretamente) tem sangue negro nas mãos
# 1108104991758274561
# Error on_data write() argument must be str, not dict
# RT @Rivotripa: A porra da base de Alcântara tava largada, servindo pra nada. Foi o Bolsonaro fazer o acordo com o Trump para a utilização d…
# 1108104992127369218
# Error on_data write() argument must be str, not dict
# RT @PauloMartins10: Quanta cretinice! https://t.co/Ol2syyA26c
# 1108104992790056960
# Error on_data write() argument must be str, not dict
# RT @ptbrasil: Submissão total a Trump!
# Bolsonaro está de joelhos nos EUA. Ele e seu ministro da Economia, Paulo Guedes, foram ao país se cu…
# 1108104993452843009
# Error on_data write() argument must be str, not dict
# RT @paulazanelli: Enquanto nossa TV tenta a todo custo destruir @folha @RedeGlobo @GloboNews
# A TV Americana FOX NEWS fez essa homenagem ao…
# 1108104993670877184
# Error on_data write() argument must be str, not dict
# RT @BolsonaroSP: Não estamos numa competição e todos os meus passos na área internacional são dados sob orientação do Ministro @ernestofara…
# 1108104993717002241
# Error on_data write() argument must be str, not dict
# RT @_pinheira: Bolsonaro: "a maioria dos imigrantes não tem boas intenções".
#
# Não tem mesmo.
#
# Em Los Angeles, 90% dos brasileiros que lá vi…
# 1108104993809289216
# Error on_data write() argument must be str, not dict
# RT @CNN: Brazilian President Jair Bolsonaro, who is sometimes called the "Trump of the Tropics," decried "fake news" and predicted US Presi…
# 1108104993926635520
# Error on_data write() argument must be str, not dict
# RT @jesustarre: Y aún hay quienes creen que eso sería anunciado por Twitter y un audio por Whatsapp &gt;&gt;&gt; Bolsonaro asegura que de haber una…
# 1108104994480361473
# Error on_data write() argument must be str, not dict
# Eu vivi pra ver 2 mitos se encontrando kkkkk https://t.co/g8qqMjZOep
# 1108104994220326913
# Error on_data write() argument must be str, not dict
# Merece ser difundido... Esas son las Palabras de quien Hoy Gobierna Brasil, y quien apoya la intervención militar e… https://t.co/wzlQcTPGvh
# 1108104994602041346
# Error on_data write() argument must be str, not dict
# RT @diputadonaranjo: Es de esperar que los parlamentarios de oposición pasemos de las palabras a los hechos.Nadie debe asistir a ninguna ac…
# 1108104994853666821
# Error on_data write() argument must be str, not dict
# Os Bolsonaros orgulham nosso voto! #BolsonaroOrgulhaOBrasil
# 1108104994903990272
# Error on_data write() argument must be str, not dict
# E vc esquerdinha, tá bravinho com o sucesso do governo Bolsonaro. Tenho dicas: #BolsonaroOrgulhaOBrasil https://t.co/O7IBKGIhaj
# 1108104994799173635
# Error on_data write() argument must be str, not dict
# RT @AmbJohnBolton: POTUS had working visit and lunch today with President Jair Bolsonaro of Brazil. They re-affirmed a new, historic partne…
# 1108104995608629251
# Error on_data write() argument must be str, not dict
# RT @peakebraga: Bolsonaro é um homem simples e humilde, não acostumado a transitar em palácios e banquetes. Mas transmite sinceridade, inte…
# 1108104995705110529
# Error on_data write() argument must be str, not dict
# RT @lelispatricia: Não! A Fox News não é esquerdista.
# É pró Trump/PartidoRepublicano, ao ponto de fazerem campanha.
#
# Isso comprova que Bo…
# 1108104995810041858
# Error on_data write() argument must be str, not dict
# até o bolsonaro teve date com o crush dele nos eua e vc nada
# 1108104996380385281
# Error on_data write() argument must be str, not dict
# “Brasil y EE.UU. nunca han estado más cerca”: Trump a Bolsonaro https://t.co/lysUvf12BO https://t.co/p3gbXj3r25
# 1108104996254433280
# Error on_data write() argument must be str, not dict
# @MiriamLeitaoCom https://t.co/2iWd6T6KGo
# 1108104996539846656
# Error on_data write() argument must be str, not dict
# RT @o_antagonista: Em entrevista a jornalistas, Jair Bolsonaro também justificou a isenção de vistos concedida a americanos. https://t.co/V…
# 1108104996996947969
# Error on_data write() argument must be str, not dict
# Analistas classificaram o apoio de Donald Trump à entrada do Brasil na OCDE como um “golaço” de Jair Bolsonaro.
#
# “É… https://t.co/gIx3kuiej5
# 1108104996262957062
# Error on_data write() argument must be str, not dict
# RT @HaddadDebochado: Vamos rir da cara dos imigrantes brasileiros que moram nos EUA que votaram massivamente em Jair Bolsonaro e ainda ouvi…
# 1108104997571567617
# Error on_data write() argument must be str, not dict
# RT @jschaulsohn: negativa de la mesa del Senado ha asistir a cena oficial con Bolsonaro por razones ideológicas es lisa y llanamente notabl…
# 1108104997638684672
# Error on_data write() argument must be str, not dict
# ⁦⁦@BolsonaroSP⁩ chama Cuba e Venezuela de “escória humana”. Trump elogia filho de Bolsonaro em pronunciamento: "tra… https://t.co/gVG1HIqeyA
# 1108104997911314433
# Error on_data write() argument must be str, not dict
# Quando Bolsonaro fala que há um rombo na Previdência ele se refere aos R$ 134 milhões que a Embaixada dos Estados U… https://t.co/GubsRW2Xji
# 1108104997923930112
# Error on_data write() argument must be str, not dict
# RT @Damadeferroofic: Ansiosa para a divulgação daquela foto marota de Bolsonaro com Donald Trump! #BolsonaroOrgulhaOBrasil
# 1108104998397898755
# Error on_data write() argument must be str, not dict
# Pessoas que por 16 anos aceitaram que seu dinheiro financiasse ditaduras no continente africano e na América latina… https://t.co/cou8U5WX56
# 1108104998968283137
# Error on_data write() argument must be str, not dict
# RT @RogerNumeriano: Hoje foi um Grande Dia, #BolsonaroOrgulhaOBrasil:
#
# - Trump declara apoio à entrada do Brasil na OCDE;
# - Trump diz q Edu…
# 1108104999303856128
# Error on_data write() argument must be str, not dict
# RT @ultrajano: Não adianta o capitão demitir embaixador nos EUA e metade do Itamaraty para melhorar sua imagem. O carimbo de fascista está…
# 1108104999702355970
# Error on_data write() argument must be str, not dict
# #BolsonaroEnvergonhaOBrasil
# 1108104999702315010
# Error on_data write() argument must be str, not dict
# RT @lareveron10: IMPORTANTE | Trump en reunión con Jair Bolsonaro, dice que evaluará "muy en serio" la idea de dar a Brasil privilegios mil…
# 1108104999991734277
# Error on_data write() argument must be str, not dict
# RT @ziberiaI: Con Cat hablaron de limones porque a la usina UTDT y a la ex Fundación Pensar le gustaba más Obama, hasta mandaron un limoner…
# 1108105000050397188
# Error on_data write() argument must be str, not dict
# RT @Press_VZLA: URGENTE
#
# DECLARACIONES A LA PRENSA DEL PRESIDENTE DE EEUU Y DE BRASIL.
#
# Presidente Bolsonaro: "La intervención militar (en…
# 1108105000352399360
# Error on_data write() argument must be str, not dict
# RT @CrisMenshova: Bolsonaro orgulha o Brasil!
# #BolsonaroOrgulhaOBrasil https://t.co/zQ1OiF6fwj
# 1108105000604106752
# Error on_data write() argument must be str, not dict
# @elpais_brasil @monicabergamo Esse é o nosso presidente BOLSONARO abafando, chora petralhaa
# 1108105000662781953
# Error on_data write() argument must be str, not dict
# RT @colominaM: Serían tres los países que encabezados por EEUU, estarían dispuestos a una intervención multilateral para sacar a Maduro:"Bo…
# 1108105001111572485
# Error on_data write() argument must be str, not dict
# RT @igorrealequatro: Amadas se um namorado te tratar igual o Trump trata o Bolsonaro eu acho que você nem precisa de...tarô
# 1108105001040338946
# Error on_data write() argument must be str, not dict
# RT @Press_VZLA: URGENTE
#
# DECLARACIONES A LA PRENSA DEL PRESIDENTE DE EEUU Y DE BRASIL.
#
# Presidente Bolsonaro: "La intervención militar (en…
# 1108105001476517889
# Error on_data write() argument must be str, not dict
# EXCLUSIVE: Eduardo Bolsonaro: Extend the Brazilian Miracle and Stop Socialism Worldwide https://t.co/dtBu4sqnop via @epochtimes
# 1108105001648443392
# Error on_data write() argument must be str, not dict
# Esse é nosso presidente ✌😎
# 1108105001526808576
# Error on_data write() argument must be str, not dict
# RT @franciscomacsoa: #BolsonaroOrgulhaOBrasil
#
# Hoje está sendo um dia histórico pro Brasil e pros USA, pras pessoas conservadoras, pra quem…
# 1108105001635844098
# Error on_data write() argument must be str, not dict
# RT @Marcelodedois: Mais coincidências https://t.co/s9kkydwzGi
# 1108105001753284613
# Error on_data write() argument must be str, not dict
# RT @BlogdoNoblat: Bolsonaro criticando o uso de fakenews é a coisa mais bizarra que se poderia ver.
# 1108105002697003009
# Error on_data write() argument must be str, not dict
# #BolsonaroOrgulhaOBrasil #BolsonaroOrgulhoDoBrasil
# 1108105002529292290
# Error on_data write() argument must be str, not dict
# RT @_AnabelG: In Trump-Bolsonaro meeting today, US supported Brazil's interest in joining OECD while Brazil agreed to forgo special &amp; diffe…
# 1108105002759962626
# Error on_data write() argument must be str, not dict
# RT @cnni: Brazilian President Jair Bolsonaro, who is sometimes called the "Trump of the Tropics," decried "fake news" and predicted US Pres…
# 1108105003170840576
# Error on_data write() argument must be str, not dict
# WantReadErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-43-c412a30a7cb3> in <module>
#      51
#      52     twitter_streamer = TwitterStreamer()
# ---> 53     twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
#
# <ipython-input-43-c412a30a7cb3> in stream_tweets(self, fetched_tweets_filename, hash_tag_list)
#      16         auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
#      17         stream = Stream(auth, listener)
# ---> 18         stream.filter(track=hash_tag_list)
#      19
#      20 class StdOutListener(StreamListener):
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /opt/conda/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /opt/conda/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /opt/conda/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# /opt/conda/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# /opt/conda/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# /opt/conda/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
